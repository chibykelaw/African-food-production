# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv')

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
pd.set_option('display.max_rows',None)

# %% [markdown]
# ## What is the total sum of Animal Fat Produced in 2014 and 2017 respectively?

# %%
#perform a groupby sum aggregration on 'Item'

df.groupby('Item').sum()
# Out:
#                                  Area Code  Item Code  Element Code  \
# Item
# Alcohol, Non-Food                    38447     752497       1515090
# Alcoholic Beverages                  75016    1649136       2171381
# Animal Products                      18060     397035         90990
# Animal fats                          85279    1882494       2567303
# Apples and products                  69280    1352989       1920418
# Aquatic Animals, Others              47420     966381       1139179
# Aquatic Plants                       51178    1057275       1278386
# Aquatic Products, Other              52570    1160712       1320249
# Bananas                              68496    1338880       1894890
# Barley and products                  76321    1432410       2243002
# Beans                                78001    1476680       2263509
# Beer                                 65975    1314720       1813728
# Beverages, Alcoholic                 65918    1313052       1807946
# ...

# %% [markdown]
# ### Result:
#     Total sum of Animal fats produced in 2014 is 209460.54
#     Total sum of Animal fats produced in 2017 is 269617.53

# %%
df.groupby('Item').get_group('Animal fats').sum()
# Out:
# Area Code                                                   85279
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                 1882494
# Item            Animal fatsAnimal fatsAnimal fatsAnimal fatsAn...
# Element Code                                              2567303
# Element         ProductionImport QuantityStock VariationExport...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                   209460.54
# Y2015                                                   200675.72
# Y2016                                                   183314.22
# Y2017                                                   269617.53
# Y2018                                                   269648.27
# dtype: object

# %% [markdown]
# ## What is the mean and Standard deviation across the whole dataset for the year 2015 to 3 decimal places?

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %% [markdown]
# ### Result:
#     The mean across the whole dataset for year 2015 is 135.236
#     The standard deviation across the whole dataset for year 2015 is 1603.404

# %% [markdown]
# ## What is the total number and percentage of missing data in 2016 to 2 decimal places?

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
for col in df.columns:
    percentage_missing = np.mean(df[col].isnull())*100
    print('{} - {}%'.format(col,percentage_missing))
# Out:
# Area Code - 0.0%
# Area - 0.0%
# Item Code - 0.0%
# Item - 0.0%
# Element Code - 0.0%
# Element - 0.0%
# Unit - 0.0%
# Y2014 - 2.6073544131401474%
# Y2015 - 2.5400784339464746%
# Y2016 - 2.5187470259094566%
# Y2017 - 2.4711615772114928%
# Y2018 - 2.356300149319856%

# %% [markdown]
# ### Result:
#     The total number and percentage of missing data in 2016 is 1535 and 2.52%

# %% [markdown]
# ## Which year had the highest correlation with 'Element Code'?

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
df.corr()*100
# Out:
#                Area Code   Item Code  Element Code       Y2014       Y2015  \
# Area Code     100.000000   -0.515910     -0.020860    0.616411    0.547166
# Item Code      -0.515910  100.000000     -2.468327    2.172208    2.085737
# Element Code   -0.020860   -2.468327    100.000000    2.445682    2.388920
# Y2014           0.616411    2.172208      2.445682  100.000000   99.464736
# Y2015           0.547166    2.085737      2.388920   99.464736  100.000000
# Y2016           0.524714    2.010913      2.344400   99.608122   99.573892
# Y2017           0.500578    2.149439      2.425401   99.522984   98.804787
# Y2018           0.566540    2.131369      2.427857   99.487166   98.820845
#
#                    Y2016       Y2017       Y2018
# Area Code       0.524714    0.500578    0.566540
# Item Code       2.010913    2.149439    2.131369
# Element Code    2.344400    2.425401    2.427857
# Y2014          99.608122   99.522984   99.487166
# ...

# %% [markdown]
# ### Result:
#     2014 (Y2014) had the highest correlation with Element Code of 2.45%

# %% [markdown]
# ## What year had the highest sum of Import Quantity?

# %%
df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# ### Result:
#     2017 (Y2017, 294559.09) has the highest sum of Import Quantity

# %% [markdown]
# ## What is the total number of the sum of production in 2014?

# %%
df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# ### Result:
#     The total number of Production in 2014 is 1931287.75

# %% [markdown]
# ## Which of these elements had the highest sum in 2018?

# %%
#select columns 'Y2018' and 'Element'

df_y2018_element = df[['Y2018','Element']]

# %%
df_y2018_element.groupby('Element').sum().sort_values(by='Y2018',ascending=False)
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Production                              2075072.89
# Food                                    1303841.28
# Total Population - Both sexes           1140605.00
# Food supply (kcal/capita/day)            455261.00
# Processing                               308429.00
# Import Quantity                          287997.09
# Feed                                     233489.68
# Export Quantity                          181594.80
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Food supply quantity (kg/capita/yr)       49056.85
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Protein supply quantity (g/capita/day)    11833.56
# Fat supply quantity (g/capita/day)        10258.69
# ...

# %% [markdown]
# ### Result:
#     Domestic supply quantity (2161192.10) is the "Element" that had the highest sum 2018.

# %% [markdown]
# ## Which of these elements had the 3rd lowest sum in 2018?

# %%
df_y2018_element.groupby('Element').sum().sort_values(by='Y2018',ascending=True)
# Out:
#                                              Y2018
# Element
# Tourist consumption                          90.00
# Fat supply quantity (g/capita/day)        10258.69
# Protein supply quantity (g/capita/day)    11833.56
# Stock Variation                           20577.91
# Seed                                      25263.14
# Residuals                                 34864.00
# Food supply quantity (kg/capita/yr)       49056.85
# Other uses (non-food)                     91300.97
# Losses                                   163902.00
# Export Quantity                          181594.80
# Feed                                     233489.68
# Import Quantity                          287997.09
# Processing                               308429.00
# Food supply (kcal/capita/day)            455261.00
# Total Population - Both sexes           1140605.00
# Food                                    1303841.28
# Production                              2075072.89
# ...

# %% [markdown]
# ### Result:
#     Protein supply quantity (g/capita/day) (11833.56) is the "Element" that had the 3rd lowest sum in 2018

# %% [markdown]
# ## What is the total Import Quantity in Algeria in 2018?

# %%
dfx = df[['Element', 'Area', 'Y2018']]

# %%
dfx.head()
# Out:
#                                   Element     Area     Y2018
# 0           Total Population - Both sexes  Algeria  42228.00
# 1                Domestic supply quantity  Algeria      0.00
# 2           Food supply (kcal/capita/day)  Algeria   3322.00
# 3  Protein supply quantity (g/capita/day)  Algeria     91.83
# 4      Fat supply quantity (g/capita/day)  Algeria     77.28

# %%
dfx1 = dfx.groupby(['Element','Area']).sum()

# %%
dfx1
# Out:
#                                                                         Y2018
# Element                                Area
# Domestic supply quantity               Algeria                       90023.42
#                                        Angola                        59590.22
#                                        Benin                         31447.90
#                                        Botswana                       3045.85
#                                        Burkina Faso                  25705.16
#                                        Cabo Verde                      731.00
#                                        Cameroon                      64009.74
#                                        Central African Republic       5567.06
#                                        Chad                          15489.73
#                                        Comoros                          19.95
# ...

# %% [markdown]
# ### Result:
#     The total Import Quantity in Algeria in 2018 is 36238.29

# %% [markdown]
# ## What is the total number of unique countries in the dataset?

# %%
df['Area'].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "C�te d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
df['Area'].nunique()
# Out:
# 49

# %% [markdown]
# ### Result:
#     The total number of unique countries in the dataset is 49
